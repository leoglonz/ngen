# %%
import geopandas as gpd

gpd.read_file(r"C:\Users\LeoLo\Desktop\noaa_owp\ngen\data\gauge_01073000\gauge_01073000.gpkg", layer='').keys()
# More than one layer found in 'gauge_01073000.gpkg': 'divides' (default), 'nexus', 'flowpaths', 'hydrolocations', 'lakes', 'network', 'flowpath_attributes', 'layer_styles'. Specify layer parameter to avoid this warning.
#
# Out:
# Index(['id', 'rl_gages', 'rl_NHDWaterbodyComID', 'Qi', 'MusK', 'MusX', 'n',
#        'So', 'ChSlp', 'BtmWdth', 'time', 'Kchan', 'nCC', 'TopWdthCC',
#        'TopWdth', 'length_m'],
#       dtype='object')

# %%
gdf = gpd.read_file(r"C:\Users\LeoLo\Desktop\jrb\jrb_2.gpkg", layers='nexus')
# 'flowpaths', 'nexus', 'divides', 'lakes', 'network', 'divide-attributes', 'flowpath-attributes', 'flowpath-attributes-ml'

gdf.head()
# Out:
# c:\Users\LeoLo\Desktop\noaa_owp\venv\Lib\site-packages\pyogrio\geopandas.py:265: UserWarning: More than one layer found in 'jrb_2.gpkg': 'flowpaths' (default), 'nexus', 'divides', 'lakes', 'network', 'divide-attributes', 'flowpath-attributes', 'flowpath-attributes-ml'. Specify layer parameter to avoid this warning.
#   result = read_func(
#            id       toid  mainstem  order  hydroseq   lengthkm   areasqkm  \
# 0    wb-88306  nex-87405   76359.0    1.0     27607   3.777694   3.253501
# 1    wb-87647  nex-87403   74069.0    1.0     27606   6.215410  10.463851
# 2    wb-88001  nex-87401   75332.0    1.0     27605   3.858419   4.144050
# 3    wb-88268  nex-88267   76217.0    1.0     27604   4.715648   5.703300
# 4    wb-88269  nex-88263   76220.0    1.0     27603   1.950208   3.329100
# ..        ...        ...       ...    ...       ...        ...        ...
# 789  wb-88404  nex-87405   76743.0    1.0     26818   4.891527   8.508600
# ...
